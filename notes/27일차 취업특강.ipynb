# %% [markdown]
# 채용 과정과 서류 전형에 관하여
#
# 1차 서류나 필기시험에서 합격하기 위한 조건과
# 실제 면접에서 합격하기 위한 조건은 서로 다를 수 있다는 점을 이해하는 것이 유리
#
# 이력서는 지원한 회사와 직무에 연관성이 높아보이게 하는 것이 유리하다(당연)
# => 무조건 많은 내용을 적는게 좋은 것이 아니라는 말!
# => 단점에 대한 부분은 적으면 거의 무조건 물어본다고 생각해라
# ==> 적기 전에 질문이 들어왔을 때 감당이 가능한지 다시 생각해볼 것

# %% [markdown]
# 존경하는 인물? -> 그 인물로 인해 받은 영향이 기업이 추구하는 방향과 맞아야...
# 하지만 차별화를 원한다면 '부모님, 유재석, 김연아'는 너무 흔하다
# => 만약 꼭 해야겠다면 확실한 스토리를 제시할 필요
#
# 대내외활동에 대한 내용
# -> 적극적이고 긍정적인 모습을 확인하기 위함. 직무 연관도가 높거나 경험 성과가 높은 것 위주로 작성하는 것이 좋음

# %% [markdown]
# 서류전형과 인적성/필기 시험은 일종의 문지기 역할이 => 그냥 최소한의 거름망
# ==> 너무 많은 노력과 시간을 들여서 고생하기보다는 부족한 부분만 빨리 채우고
#     이후의 것들을 준비하는 것이 더 유리할 가능성이 크다
#
# 그럼 이력서/자소서 중에 뭐가 더 중요하냐?
# 이력서는 정량 평가 - 자소서는 정성 평가
# => 회사와 직군별로 차이가 크지만, 평균적으로 이력서 7 : 자소서 3 정도

# %% [markdown]
# 아르바이트나 업무 경험이 카페나 식당 등 서비스업에 치우쳐있는 경우, 성격이나 관심이 그쪽에 치우쳐있는 것은 아닌지 확인하고자 질문할 가능성
# => 사실대로 대답하되 업무적 강점에 대해서도 재차 강조할 필요성

# %% [markdown]
# 자기소개서 작성 포인트
#
# 기업분석 / 직무분석 / 나 분석
# 이렇게 세 분야에 대한 분석이 선행되어야 함
#
# 1. 기업분석
#     a) 기업의 현황파악
#         기업의 종류(주식회사, 유한회사, 협동조합 등),
#         조직구성, 사업 종류, 회사 현황 등
#     b) 산업 분야의 이슈
#         해당 사업이 속한 산업의 최근 이슈와 배경
#     c) 최근 수행중인 사업의 성과 및 이슈
#
#     기업공시 - 다트 / 알리오, 클린아이, 대학알리미
#     보도자료 - 뉴스 포털 / 회사 공식 홈페이지
#     현직자 인터뷰 - 지도교수님 추천 선배, SNS(인스타, 링크드인 등)
#     채용설명회 - 각 기업들 공시, 온/오프라인
#     지원회사 방문 - 공무원,공공기관, 공기업 등은 추천하는 방법(사기업 비추)
#
#     회사의 주력 서비스 확인 - 내가 취직 후 하게 될 일이라는 생각으로 보기
#         사업 영역이나, 마켓 사이즈 확인하고, 경쟁사와 비교해보기
#
#     회사의 서비스 이용해보기 - 사용 후 장단점 분석
#
#     회사의 투자상황 확인해보기 - 취업했는데 월급 안나오면 울고싶...
#
#     회사의 채용 페이지를 반드시 확인 - 키워드/용어를 잘 확인하고 자소서나 면접에도
#         잘 녹여서 말할 수 있도록
#
# 2. 직무분석
#     a) 직무 수행에 필요한 지식
#     b) 기술
#     c) 성격
#
# 3. 나 분석
#     a) 지원 직무 역량과 관련한 나의 과거 성취 경험
#     b) 지원 산업 분야와 관련한 나이 과거 성취 경험
#     c) 과거 성과 경험
#
# 비전과 계획을 묻는 부분에서는 아주아주 상세하고 소상한 계획이 필요하다
# => 사업계획서처럼 진짜 그렇게 할 것이라고 믿을 수 있을 정도로!
#
# 요즘 자소서는 문항별로 500~700자 정도로 정리하는 것이 읽는 쪽에도 좋더라
#     1000자 까지 가버리면 한번이 읽기 좀 힘들어서...
#     500자 정도면 한눈에 구조가 들어오고 읽기 편함

# %% [markdown]
# 시기 / 이벤트 내용 / 얻은 역량
#
# 엑셀에 나눠서 쭉 정리해보면 내가 어떤 사람인지 도움이 될 것
# 일단 정리해두고 보면 어떤 소재들을 자소서에 쓸 수 있을지 보인다
#
# 글을 잘 쓰고 싶다면 구조를 잘 잡아야 한다!
# 그래야 많은 글을 빠르게 쓸 수 있다...ㅎ
# 질문의 유형별로 글의 구조를 잡아서 써나가면 편하다
#
# 사례 키워드 + 성과 키워드 (+ 역량 키워드)를 통해 소제목 작성
# 300자 미만의 경우 첫 문장을 소제목 형태로 작성하기 시작하면 된다
#
# 글자수는 가능하면 꽉 채워서 작성하되, 숫자 채우겠다고 의미없는 말로 채우지 마라.

# %% [markdown]
# 1. 문제를 해결하기 위해 노력했던 경험에 대해, 당시의 문제사항, 자신의 역할, 해결을 위한 노력, 결과 등을 상세히 기술하시오. (500자 이내)
#
# [소재 선택 가이드]
# ·지원한 직무와 관련한 경험 중에서도 성과를 표현할 수 있는 경험이 좋은 소재 입니다.
#
# [작성가이드]
# ·해당 경험 내에서 목표나, 역할, 문제를 해결하기 위한 나이노력이 잘 드러나도록 기술해보세요.
# ·짧은 문장이 좋은 문장입니다.
# ·작성의 주체가 '나'이므로 저는 이라는 표현은 되도록 삭제합니다.
#
# [내용 구성법]
# ·두괄식 경험 소개 : 00을 하면서 ~~을 한 적이 있습니다.
# ·상황 : 당시, ~~ (역할, 목표, 어려움 등)
# ·대처 : 그래서 (내가 한 행동, 방법 등)
# ·결과 : 그 결과 (성과, 차별점, 효율화 등 수치표현)
# ·느낀점 및 포부 : 이를 통해 ~ . 앞으로도 ~~.

# %% [markdown]
# 2. 본인의 장/단점과 입사 후 장점은 어떻게 활용되고, 단점은 어떻게 보완 할 수 있겠는지를기술하세요 (500자 이내)
#
# [소재 선택 가이드]
# ·성향 및 선천적 기질을 물어보는 문항으로 독특한 소재보다는 해당 직무를 수행하거나 조직 적합성이 높은 소재를 선택합니다.
# ·장점은 사례를 들되, 해당 사례는 반드시 직무와 연관되지 않아도 됩니다.
# ·단점은 사례를 들지 않고, 보완노력으 기재합니다. 단점 기재시 '다소', '간혹', '가끔' 등의 부사를 사용해 글의 뉘앙스를 조절해보세요.
#
# [작성가이드]
# ·짧은 문장이 좋은 문장입니다.
# ·작성의 주체가 '나'이므로 저는 이라는 표현은 되도록 삭제합니다.
#
# [내용 구성법]
# 장점 :
# 장점을 발휘한 성취한 사례 :
# 단점 :
# 보완노력 2가지 :
# 마무리 (포부) :

# %% [markdown]
# 1. 역량을 먼저 정리 2. 그에 따른 성취경험 3. 자기소개 순으로 준비해라!

# %% [markdown]
# 자신의 역량을 정리할 때 마인드맵 형태로 정리하면 좀 더 쉽게 기억할 수 있다
#     시기별 엑셀 정리로 잘 정리해보자

# %% [markdown]
# 면접은 보고 스피치이다. 불필요한 말은 빼자
# 문장은 짧게 구성하되, 논리적 연결어로 조금 더 부드럽게 해주자
# 비즈니스 매너를 갖춘 어미처리를 하자
# 두괄식 멘트, 정리멘트, 브릿지멘트, 넘버링을 적극 활용
# 회사나 산업, 직무가 좋아하는 키워드를 사용하자
# 신뢰도 향상을 위해 적절한 목소리와 비언어적 표현 사용하자

# %% [markdown]
# 면접의 기본
# 유재석의 Good Point
# 입장부터 바른 자세로 인사! -> 아주 기본적인 비즈니스 매너
# 질문에 대해 포인트를 한번쯤 생각해보고 자신의 주장과 더불어
# 논리적 근거를 적절히 제시하는 모습
# 퇴장할 때에도 자리를 잘 정리하고 나가는 모습
#
# 조세호의 Bad Point
# 봇짐을 풀어놓는다고 했는데 마무리를 못했다!
# -> 그럼 무엇이 들어있어야 했나.... => 이 회사에 입사하기 위한 역량들이 있습니다!
# -> 그것만 잘 답했어도 센스있고 재미있는 면접이 되었을 것
#
# 당일에는 당연히 미리 도착해서 그 자리에 조금이라도 익숙해지면 안정도 UP
# 면접 성공률도 UP 그러나 너무 일찍은 좀... ㅎ (5~10분이 적절)
#
# 제출한 이력서 다시 읽어보기, 입퇴장시 목례는 기본

# %% [markdown]
# 기술 면접에 대해
# 기초 CS에 대한 부분은 기본! - 알아서 공부하자
# 바로 아는 척 하지 마라! - 괜히 아는척 해봐야 이어지는 질문에 금방 드러난다
#     오히려 나쁜 태도로 보여질 수 있다 -> 완곡히 모른다고 표현하자
#
# 프로젝트 소개 한두문장 + 기술적으로 고민했던 내용 1~3 + 해결방안과 느낀점은 기본 준비

# %% [markdown]
# 인성면접(컬처핏)
# 인성 면접의 질문에는 정답이 없다! -> 그저 본인의 생각과 근거를 잘 말하도록 하자
#     자신의 가치관을 잘 보여줄 수 있도록
#
# 입장을 변경하는 것은 좋지 않지만, 명백하게 자신의 의견이 틀렸다는 것을 인정해야하는 상황에서는 받아들이는 것이 좋다

# %% [markdown]
# 취업 준비 중에 할 활동들 중에서
# 창의성이 필요하고, 새롭게 시도하는 일들은 주로 오전에 채운다!
# 루틴하고, 반복해서 해야하는 일들은 주로 오후에 채운다!

# %% [markdown]
# 면접에 긴장이 많이 된다면, 정말 많이 준비한게 맞는지 다시 생각해보자...
# 더 많이 준비하면 덜 떨릴 것이다 ㅎ
#
# 경력이 없더라도 그 외의 것들을 정말 많이 준비하면 (면접 등) 합격 가능하다.
