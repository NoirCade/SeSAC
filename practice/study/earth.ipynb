# %%
import pandas as pd
import os

path = 'C:/Users/kth53/Downloads/earthquakes.csv'

data = pd.read_csv(path)
data
# Out:
#                                     time   latitude   longitude    depth  \
# 0       1990-01-01 00:22:33.990000+00:00  61.730200 -149.669200   30.100
# 1       1990-01-01 01:03:44.490000+00:00  34.546000 -118.934000   16.122
# 2       1990-01-01 01:04:13.760000+00:00  34.543000 -118.923000   16.342
# 3       1990-01-01 02:47:41.250000+00:00  36.323000   26.969000  144.800
# 4       1990-01-01 03:27:39.630000+00:00  38.799833 -122.805667    1.368
# ...                                  ...        ...         ...      ...
# 810668  2024-03-13 22:10:34.819000+00:00 -19.747000  -71.033300   11.279
# 810669  2024-03-13 22:14:59.103000+00:00 -19.745100  -71.026300   23.831
# 810670  2024-03-13 22:38:03.016000+00:00 -19.757400  -71.049500   20.403
# 810671  2024-03-13 22:50:12.007000+00:00 -19.710800  -71.081100   23.834
# 810672  2024-03-13 23:05:04.022000+00:00 -19.692500  -71.069300    9.761
#
#          mag magType   nst    gap     dmin    rms  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810673 entries, 0 to 810672
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             810673 non-null  object
#  1   latitude         810673 non-null  float64
#  2   longitude        810673 non-null  float64
#  3   depth            810672 non-null  float64
#  4   mag              810673 non-null  float64
#  5   magType          810672 non-null  object
#  6   nst              436570 non-null  float64
#  7   gap              552412 non-null  float64
#  8   dmin             289633 non-null  float64
#  9   rms              691860 non-null  float64
#  10  net              810673 non-null  object
#  11  id               810673 non-null  object
#  12  updated          810673 non-null  object
#  13  place            810673 non-null  object
#  14  type             810673 non-null  object
#  15  horizontalError  296508 non-null  float64
# ...

# %%
data_drop = data[['time', 'latitude', 'longitude', 'depth', 'mag']]

# %%
data_drop = data_drop.dropna()

# %%
data_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 810672 entries, 0 to 810672
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       810672 non-null  object
#  1   latitude   810672 non-null  float64
#  2   longitude  810672 non-null  float64
#  3   depth      810672 non-null  float64
#  4   mag        810672 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 37.1+ MB

# %%
data_drop.head()
# Out:
#                                time   latitude   longitude    depth   mag
# 0  1990-01-01 00:22:33.990000+00:00  61.730200 -149.669200   30.100  2.50
# 1  1990-01-01 01:03:44.490000+00:00  34.546000 -118.934000   16.122  2.95
# 2  1990-01-01 01:04:13.760000+00:00  34.543000 -118.923000   16.342  2.77
# 3  1990-01-01 02:47:41.250000+00:00  36.323000   26.969000  144.800  3.30
# 4  1990-01-01 03:27:39.630000+00:00  38.799833 -122.805667    1.368  2.51

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(data_drop)

# 각 컬럼의 값들의 분포를 히스토그램으로 나타내기
fig, axs = plt.subplots(1, len(df.columns[1:]), figsize=(15, 5))

for i, col in enumerate(df.columns[1:]):
    axs[i].hist(df[col], bins=10, color='blue', alpha=0.7)
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')
    axs[i].set_title(f'Distribution of {col}')
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# %%
ex_mag = 10**(data_drop['mag'].values)

# %%
ex_mag
# Out:
# array([  316.22776602,   891.25093813,   588.84365536, ...,
#        15848.93192461, 19952.62314969, 39810.71705535])

# %%
data_drop['ex_mag'] = ex_mag

data_drop
# Out:
#                                     time   latitude   longitude    depth  \
# 0       1990-01-01 00:22:33.990000+00:00  61.730200 -149.669200   30.100
# 1       1990-01-01 01:03:44.490000+00:00  34.546000 -118.934000   16.122
# 2       1990-01-01 01:04:13.760000+00:00  34.543000 -118.923000   16.342
# 3       1990-01-01 02:47:41.250000+00:00  36.323000   26.969000  144.800
# 4       1990-01-01 03:27:39.630000+00:00  38.799833 -122.805667    1.368
# ...                                  ...        ...         ...      ...
# 810668  2024-03-13 22:10:34.819000+00:00 -19.747000  -71.033300   11.279
# 810669  2024-03-13 22:14:59.103000+00:00 -19.745100  -71.026300   23.831
# 810670  2024-03-13 22:38:03.016000+00:00 -19.757400  -71.049500   20.403
# 810671  2024-03-13 22:50:12.007000+00:00 -19.710800  -71.081100   23.834
# 810672  2024-03-13 23:05:04.022000+00:00 -19.692500  -71.069300    9.761
#
#          mag         ex_mag
# 0       2.50     316.227766
# 1       2.95     891.250938
# ...
