# %%
from PyKakao import Karlo

key = '3765128415d018ad0f22a4652626fda8'
k=Karlo(service_key=key)

text = 'Cute magical flying cat soft golden fur, fantasy art drawn by Pixar concept artist,\
    Toy Story main character, clear and bright eyes, sharp nose'

data = k.text_to_image(text,0)

# %%
imgUrl = data['images'][0]['image']

# %%
import requests
from PIL import Image

imageData = requests.get(imgUrl, stream=True).raw
Image.open(imageData)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>

# %%
text = 'Datasturcture hash table, describes it\'s features'

data = k.text_to_image(text,0)
imgUrl = data['images'][0]['image']
imageData = requests.get(imgUrl, stream=True).raw
Image.open(imageData)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>
