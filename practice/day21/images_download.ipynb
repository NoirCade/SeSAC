# %%
from glob import glob

## 작업할 이미지 폴더 경로 설정 + 맨 끝에 /* 추가
file_paths = glob('C:/Users/bluecom015/Downloads/soccer_data/data/Training/source/instep_male/*.jpg')

data = []
for i in file_paths:
    data.append(i.split('\\')[-1])


s = '_'.join(data[0].split('_')[:-1])
data2 = []
tmp = []
for idx, i in enumerate(data):
    a = i.split('_')
    b= a[-1].split('.')
    if '_'.join(a[:-1]) != s:
        data2.append(tmp)
        tmp = []
        tmp.append(i)
        s = '_'.join(a[:-1])
    else: tmp.append(i)

picture_data = []
cnt =1
for x in data2:
    num = 0
    for idx, y in enumerate(x):
        if num < int(y.split('.')[1][y.split('.')[1].find('e')+1:]):
            num = int(y.split('.')[1][y.split('.')[1].find('e')+1:])
            max_idx = idx
    picture_data.append(x[max_idx])
    cnt +=1

picture_data
# Out:
# ['a01mr1_041_2aa_2070022.941_20220920_0681_a-01_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-02_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-03_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-04_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-05_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-06_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-07_frame606.jpg',
#  'a01mr1_041_2aa_2070022.941_20220920_0681_a-08_frame606.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-01_frame623.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-02_frame623.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-03_frame623.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-04_frame623.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-05_frame623.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-06_frame623.jpg',
#  'a01mr1_042_2aa_2070022.941_20220920_0682_a-07_frame623.jpg',
# ...

# %%
from PIL import Image

## 작업할 이미지 폴더 경로 설정
file_path = 'C:/Users/bluecom015/Downloads/soccer_data/data/Training/source/instep_male/'

for x in picture_data:
    img = Image.open(file_path+x)
    img.save('C:/Users/bluecom015/Downloads/soccer_data/data/Training/source/selected/'+x)  ## 저장할 폴더 경로 설정
