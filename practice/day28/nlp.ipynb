# %% [markdown]
# 자료1
# 환경을 위해서 오전 출근시간에 탄소배출권을 실시하겠습니다.\n
# 육아휴직을 장려하겠습니다.
#
# 자료2   자료1.split('\n')
# ['환경을 위해서 오전 출근시간에 탄소배출권을 실시하겠습니다.', '육아휴직을 장려하겠습니다.']
#
# 자료3   noun_extractor.extract(자료2)
# [['환경', '오전', '출근', '탄소', '배출'],
# ['육아', '휴직', '장려']]
#
# 자료4   자료3을 이용한 전처리(불용어, 치환) / 하지만 이것은 자료1부터 해도 됨
# [['환경', '출근', 'co2', '배출']
# ['육아', '휴직', '장려']]
#
# 자료4를 이용해서 워드클라우드 한다면 반드시 한 개의 리스트에 있는 자료들로 해야함
# ==> ['환경', '출근', 'co2' '배출', '육아', '휴직', '장려'] 이런 식으로 바꿔야함

# %% [markdown]
# 방사형 차트 - 주로 고객 평가 점수에서 많이 이용됨. 영화 평가 등
# 각 데이터의 치우침 정도를 나타내기 위해 사용!
#
# TSNE = 벡터화 모듈 - nlp 뿐만 아니라 딥러닝에도 자주 사용
